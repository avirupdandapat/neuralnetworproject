# %%
pip install --upgrade pip
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 14.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 25.1.1
#     Uninstalling pip-25.1.1:
#       Successfully uninstalled pip-25.1.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Core stack (CPU)
# !pip install numpy==1.26.4
# !pip install torch==2.3.1 torchvision==0.18.1 torchaudio==2.3.1

# Utilities
# !pip install pandas==2.2.2 scikit-learn==1.5.1 matplotlib==3.9.0 tqdm==4.66.4 pillow==10.3.0

# %%
pip install --upgrade "numpy==1.26.4" "scipy==1.11.4" "scikit-learn==1.4.2"

# %%
# === Cell 1: Imports & config ===
import os, random, shutil, json
from pathlib import Path
import numpy as np
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets, models, transforms
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# Reproducibility
SEED = 42
random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED)

# %%
# Paths (edit DATA_ROOT to your extracted Kaggle folder)
DATA_ROOT = Path("Human Bone Fractures Multi-modal Image Dataset (HBFMID)/Bone Fractures Detection")   # <- adjust if needed
#WORK_DIR  = Path("runs/bone_region_cls"); WORK_DIR.mkdir(parents=True, exist_ok=True)
