# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import inspect

# %%
# !pip install RLC
# Out:
# Requirement already satisfied: RLC in /Users/avirup.dandapat/.pyenv/versions/3.12.4/envs/my-nn-venv/lib/python3.12/site-packages (0.3)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install python-chess  # Python-Chess is the Python Chess Package that handles the chess environment
# !pip install --upgrade git+https://github.com/arjangroen/RLC.git  # RLC is the Reinforcement Learning package
# Out:
# Collecting python-chess
#   Downloading python_chess-1.999-py3-none-any.whl.metadata (776 bytes)
# Collecting chess<2,>=1 (from python-chess)
#   Downloading chess-1.11.2.tar.gz (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 18.5 MB/s  0:00:00 eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Downloading python_chess-1.999-py3-none-any.whl (1.4 kB)
# Building wheels for collected packages: chess
#   Building wheel for chess (pyproject.toml) ... done
#   Created wheel for chess: filename=chess-1.11.2-py3-none-any.whl size=147878 sha256=efcb14f9a2d2f1d27ca0feeddec63a32b76d3facc7dca51d18b25072337898ec
#   Stored in directory: /Users/avirup.dandapat/Library/Caches/pip/wheels/83/1f/4e/8f4300f7dd554eb8de70ddfed96e94d3d030ace10c5b53d447
# Successfully built chess
# Installing collected packages: chess, python-chess
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [python-chess]
# Successfully installed chess-1.11.2 python-chess-1.999
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Collecting git+https://github.com/arjangroen/RLC.git
#   Cloning https://github.com/arjangroen/RLC.git to /private/var/folders/zl/t01vmy2d01b_mdym1ysx95f5yg807f/T/pip-req-build-ylbajvos
#   Running command git clone --filter=blob:none --quiet https://github.com/arjangroen/RLC.git /private/var/folders/zl/t01vmy2d01b_mdym1ysx95f5yg807f/T/pip-req-build-ylbajvos
#   Resolved https://github.com/arjangroen/RLC.git to commit e54eb7380875f64fd06106c59aa376b426d9e5ca
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: RLC
#   Building wheel for RLC (pyproject.toml) ... done
#   Created wheel for RLC: filename=rlc-0.3-py3-none-any.whl size=22581 sha256=a943a95654bb0b031b878cb25908890ddd8f505c8706b59cf591a92d4dcdcee0
#   Stored in directory: /private/var/folders/zl/t01vmy2d01b_mdym1ysx95f5yg807f/T/pip-ephem-wheel-cache-8p0yxl0x/wheels/c4/c3/ab/bdeb7ba0931dd1181093c01b544b0bcd5e38f806fd3f843c0f
# Successfully built RLC
# Installing collected packages: RLC
# Successfully installed RLC-0.3
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from RLC.move_chess.environment import Board
from RLC.move_chess.agent import Piece
from RLC.move_chess.learn import Reinforce
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from RLC.move_chess.environment import Board
#       2 from RLC.move_chess.agent import Piece
#       3 from RLC.move_chess.learn import Reinforce
#
# ModuleNotFoundError: No module named 'RLC'

# %%
import os
print(os.getcwd())
# Out:
# /Users/avirup.dandapat/Desktop/neuralnetworproject/RL

# %%
import sys
sys.path.append('/private/var/folders/zl/t01vmy2d01b_mdym1ysx95f5yg807f/T/pip-ephem-wheel-cache-8p0yxl0x/wheels/c4/c3/ab/bdeb7ba0931dd1181093c01b544b0bcd5e38f806fd3f843c0f')
from RLC.move_chess.environment import Board
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 import sys
#       2 sys.path.append('/private/var/folders/zl/t01vmy2d01b_mdym1ysx95f5yg807f/T/pip-ephem-wheel-cache-8p0yxl0x/wheels/c4/c3/ab/bdeb7ba0931dd1181093c01b544b0bcd5e38f806fd3f843c0f')
# ----> 3 from RLC.move_chess.environment import Board
#
# ModuleNotFoundError: No module named 'RLC'
